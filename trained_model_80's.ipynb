# %% [markdown]
# # Spotify Hit Predictor model for 80's Dataset

# %% [markdown]
# ### Load Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import joblib
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
import matplotlib as mpl #add'l plotting functionality

mpl.rcParams['figure.dpi'] = 400 #high res figures
plt.style.use('dark_background')

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv('dataset-of-80s.csv')
df.head
# Out:
# <bound method NDFrame.head of                                                   track             artist  \
# 0                                         Walking Blues   Big Joe Williams
# 1                                  Suddenly Last Summer         The Motels
# 2                                             Sanctuary         Béla Fleck
# 3                                        The Wild Rover         The Pogues
# 4                                  In The Driver's Seat     John Schneider
# ...                                                 ...                ...
# 6903  Bachke Rehna Re Baba - Pukar / Soundtrack Version      Kishore Kumar
# 6904                                  Tiempos Metálicos                 V8
# 6905                                                Joy  Teddy Pendergrass
# 6906                                I Wanna Be A Cowboy     Boys Don't Cry
# 6907                                    Hot In The City         Billy Idol
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:1ZjN5X8LmUB67pWPgimW3B         0.509   0.277    6
# 1     spotify:track:4fLIM0B1WwrLux9RdnMvze         0.716   0.753    2
# 2     spotify:track:3DwlNfiCQSdj0GOxYkR9Rq         0.360   0.542    5
# 3     spotify:track:6JyYNPLalPgGa7XnclF5FO         0.656   0.512    7
# 4     spotify:track:6jJi8OXF5qaFdysB6sjWIT         0.642   0.889    2
# ...                                    ...           ...     ...  ...
# 6903  spotify:track:2wK3g7TTQa9AJMKcuYKbon         0.443   0.589    7
# 6904  spotify:track:3QaUanfuOovKQ5yNgGOSsz         0.208   0.750    9
# 6905  spotify:track:2Qv5EUATFNebcFGq3rN8O6         0.739   0.729    4
# 6906  spotify:track:38mEFmht9K7UcpHvS9vtJG         0.749   0.626    0
# 6907  spotify:track:5LeDMHIZ5YDZ2b1VOcYVcG         0.660   0.897    5
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0      -14.323     1       0.0495      0.827000          0.002060    0.0756
# 1       -5.682     1       0.0286      0.162000          0.030600    0.0831
# 2      -13.885     1       0.0339      0.368000          0.165000    0.1160
# 3      -11.872     1       0.0290      0.585000          0.000000    0.0720
# 4       -5.620     0       0.0494      0.375000          0.000000    0.1800
# ...        ...   ...          ...           ...               ...       ...
# 6903    -8.085     1       0.0392      0.552000          0.000000    0.1410
# 6904   -12.945     1       0.1080      0.000134          0.000002    0.0621
# 6905    -9.694     0       0.0572      0.249000          0.007680    0.0690
# 6906   -12.426     1       0.0393      0.011500          0.567000    0.0558
# 6907    -5.558     1       0.0257      0.003160          0.000023    0.1160
#
#       valence    tempo  duration_ms  time_signature  chorus_hit  sections  \
# 0       0.640  101.157       161893               4    68.46530         7
# 1       0.561  120.141       222000               4    57.71583        11
# 2       0.803  116.831       444907               4    30.34574        17
# 3       0.880   97.500       157893               3    50.97022         7
# 4       0.764  163.351       162293               4    33.62053         7
# ...       ...      ...          ...             ...         ...       ...
# 6903    0.963   97.401       384360               4    31.61135        23
# 6904    0.394   83.467       154827               4    23.71780         8
# 6905    0.884  103.339       375652               4    31.31730        13
# 6906    0.770  142.565       366133               4    27.71571        18
# 6907    0.670  111.193       219133               4    51.40399         9
#
#       target
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
# ...      ...
# 6903       0
# 6904       0
# 6905       1
# 6906       1
# 6907       1
#
# [6908 rows x 19 columns]>

# %%
df.shape
# Out:
# (6908, 19)

# %% [markdown]
# 6398 smaples having 19 features.

# %% [markdown]
# ### Shuffle The Data

# %%
df = df.sample(frac = 1)

# %% [markdown]
# ### Balance The Dataset

# %% [markdown]
# #### Dropping Categorical features

# %%
X = df.drop(['target', 'track', 'artist', 'uri'], axis=1)

# %%
X.shape
# Out:
# (6908, 15)

# %% [markdown]
# Modified dataframe X

# %%
Y = df['target']

# %% [markdown]
# Now lets check if hits and flops counts are balanced

# %%
hit_flop_count = Y.value_counts()

# %%
hit_flop_count
# Out:
# 1    3454
# 0    3454
# Name: target, dtype: int64

# %% [markdown]
# We observe that dataset target values of hits and flops are well balanced.i.e, equal.

# %%
Y = Y.values

# %% [markdown]
# ### Standardize The Inputs

# %%
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %% [markdown]
# ### Split The Dataset into Train,Validation and Test

# %% [markdown]
# Training and Testing split (ratio of 90% to 10% respectively)

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_X, Y, test_size=0.1, random_state=1)

# %% [markdown]
# Training and Validation split

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=(1/9), random_state=1)

# %%
x_train.shape, x_test.shape, x_val.shape
# Out:
# ((5526, 15), (691, 15), (691, 15))

# %% [markdown]
# ### Create The Deep Learning Algorithm

# %% [markdown]
# Using standard notations used globally for training neural networks

# %%
nn = 200 #number of neurons in hidden layers
target_count = 2

# %%
model_80 = tf.keras.Sequential()
model_80.add(tf.keras.layers.Flatten())

# %%
model_80.add(tf.keras.layers.Dense(nn, activation=tf.nn.relu))# first hidden  layer
model_80.add(tf.keras.layers.Dense(nn, activation=tf.nn.relu))# second hidden layer
model_80.add(tf.keras.layers.Dense(nn, activation=tf.nn.relu))# third hidden layer

# %%
model_80.add(tf.keras.layers.Dense(target_count, activation=tf.nn.softmax))# output layer

# %%
model_80.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### Fitting the model

# %%
model_fit = model_80.fit(x_train, y_train, epochs=20, validation_data=(x_val, y_val), batch_size=100)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 1s 14ms/step - loss: 0.4931 - accuracy: 0.7626 - val_loss: 0.4651 - val_accuracy: 0.7829
# Epoch 2/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4374 - accuracy: 0.7979 - val_loss: 0.4821 - val_accuracy: 0.7685
# Epoch 3/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4202 - accuracy: 0.8089 - val_loss: 0.4555 - val_accuracy: 0.7858
# Epoch 4/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.4069 - accuracy: 0.8147 - val_loss: 0.4813 - val_accuracy: 0.7742
# Epoch 5/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3975 - accuracy: 0.8228 - val_loss: 0.4899 - val_accuracy: 0.7699
# Epoch 6/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3875 - accuracy: 0.8263 - val_loss: 0.4899 - val_accuracy: 0.7728
# Epoch 7/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3713 - accuracy: 0.8326 - val_loss: 0.4913 - val_accuracy: 0.7771
# Epoch 8/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3695 - accuracy: 0.8315 - val_loss: 0.4858 - val_accuracy: 0.7800
# Epoch 9/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3588 - accuracy: 0.8353 - val_loss: 0.4966 - val_accuracy: 0.7641
# Epoch 10/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3488 - accuracy: 0.8487 - val_loss: 0.4889 - val_accuracy: 0.7902
# Epoch 11/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3353 - accuracy: 0.8543 - val_loss: 0.5235 - val_accuracy: 0.7540
# Epoch 12/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3195 - accuracy: 0.8619 - val_loss: 0.5342 - val_accuracy: 0.7670
# Epoch 13/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.3100 - accuracy: 0.8648 - val_loss: 0.5317 - val_accuracy: 0.7583
# Epoch 14/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2978 - accuracy: 0.8708 - val_loss: 0.5793 - val_accuracy: 0.7598
# Epoch 15/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2901 - accuracy: 0.8791 - val_loss: 0.5374 - val_accuracy: 0.7742
# Epoch 16/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2789 - accuracy: 0.8826 - val_loss: 0.5761 - val_accuracy: 0.7583
# Epoch 17/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2650 - accuracy: 0.8831 - val_loss: 0.6042 - val_accuracy: 0.7670
# Epoch 18/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2372 - accuracy: 0.9048 - val_loss: 0.6381 - val_accuracy: 0.7641
# Epoch 19/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2357 - accuracy: 0.9017 - val_loss: 0.6140 - val_accuracy: 0.7771
# Epoch 20/20
# 56/56 [==============================] - 0s 4ms/step - loss: 0.2198 - accuracy: 0.9092 - val_loss: 0.6307 - val_accuracy: 0.7757

# %%
#Storing the predictions
predictions = model_80.predict(x_test)

# %% [markdown]
# ### Visualize Neural Network Loss History

# %% [markdown]
# #### Loss Variation Plot

# %%
training_loss = model_fit.history['loss']
validation_loss = model_fit.history['val_loss']
epoch_count1 = range(1, len(training_loss) + 1)

# %%
plt.subplot(2,1,2)
plt.title('Loss Variation Plot')
plt.plot(epoch_count1, training_loss, color='violet', label='Training Loss')
plt.plot(epoch_count1, validation_loss, color='indigo', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# #### Accuracy Variation Plot

# %%
training_acc = model_fit.history['accuracy']
validation_acc = model_fit.history['val_accuracy']
epoch_count2 = range(1, len(training_acc) + 1)

# %%
plt.subplot(2,1,2)
plt.title('Accuracy Variation Plot')
plt.plot(epoch_count2, training_acc, color='red', label='Training Accuracy')
plt.plot(epoch_count2, validation_acc, color='green', label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %% [markdown]
# ### Test The Model

# %%
print(predictions[215])
print('Predicted:', np.argmax(predictions[215]))
print('Original:', y_test[215])
# Out:
# [0.12983485 0.87016517]
# Predicted: 1
# Original: 1

# %% [markdown]
# ### Saving model and Verifying

# %%
model_80.save('Trained_model_80')
# Out:
# WARNING:tensorflow:From c:\users\shash\anaconda3\envs\demo\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From c:\users\shash\anaconda3\envs\demo\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: Trained_model_80\assets

# %%
model = tf.keras.models.load_model('Trained_model_80')
print(x_test[1])
# Out:
# [-0.27305516  0.87659197 -0.06487449  0.20955574  0.67402952 -0.24593373
#  -0.32042818 -0.4854273  -0.55055369  1.27881957  2.14919475 -0.36462683
#   0.20673746 -0.93287718 -0.06208929]

# %%
print(x_test[1].reshape( 1,-1))
# Out:
# [[-0.27305516  0.87659197 -0.06487449  0.20955574  0.67402952 -0.24593373
#   -0.32042818 -0.4854273  -0.55055369  1.27881957  2.14919475 -0.36462683
#    0.20673746 -0.93287718 -0.06208929]]

# %%
v = model.predict(x_test[1].reshape( 1,-1))
print(v)
# Out:
# [[0.3086944  0.69130564]]
